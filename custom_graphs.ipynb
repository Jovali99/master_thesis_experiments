# %%
from src.utils import sigmoid_weigths
from src.save_load import savePlot
import numpy as np
import matplotlib.pyplot as plt

# %%
# ----------- #
#   Sigmoid   #
# ----------- #
scores = np.linspace(0, 1, 500)
centrality = 0.5
temp = 0.1
weights = sigmoid_weigths(scores, centrality=centrality, temperature=temp)
print(max(weights))

plt.figure(figsize=(6, 4))
plt.axvline(centrality, linestyle="--", alpha=0.6, label="centrality")
plt.plot(scores, weights)
plt.xlabel("RMIA Vulnerability Score")
plt.ylabel("Weight")
plt.title("Sigmoid Weighting Function")
plt.grid(True, alpha=0.3)
plt.tight_layout()
fig = plt.gcf()
fig.show()

#savePlot(fig, f"sigmoid_po", "graphs", ".")
